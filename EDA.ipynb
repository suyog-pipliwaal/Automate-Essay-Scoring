# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
root_dir = "./data/"
train_data_path = "./data/train.csv"
test_data_path = "./data/test.csv"

# %%
train_df = pd.read_csv(train_data_path)
print(f"number of samples are {len(train_df)}")
# Out:
# number of samples are 17307

# %% [markdown]
# ## Length vs score distribution

# %%
train_df['length'] = train_df['full_text'].apply(lambda x: len(x))
train_df.plot(figsize=(10, 10), x='length', y='score', kind='bar')
# Out:
# <Axes: xlabel='length'>

# %%
train_df['score'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
train_df['length'].value_counts()
# Out:
# 1302    19
# 1514    19
# 1565    18
# 1364    18
# 1296    18
#         ..
# 4934     1
# 3480     1
# 3232     1
# 5452     1
# 4283     1
# Name: length, Length: 3495, dtype: int64

# %%
train_df['length'].describe()
# Out:
# count    17307.000000
# mean      2071.617265
# std        925.910701
# min        712.000000
# 25%       1397.000000
# 50%       1924.000000
# 75%       2541.000000
# max      20459.000000
# Name: length, dtype: float64
